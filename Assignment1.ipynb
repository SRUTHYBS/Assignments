# %% [markdown]
# # Qn1. Read the dataset to python environment.

# %%
#To import pandas
import pandas as pd
#To read dataset
data=pd.read_csv('iris.csv')
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Qn2. Display the columns in the dataset.

# %%
#To display column headings
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#To display each column
data['SL']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SL, Length: 150, dtype: float64

# %%
data['SW']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SW, Length: 150, dtype: float64

# %%
data['PL']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PL, Length: 150, dtype: float64

# %%
data['PW']
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PW, Length: 150, dtype: float64

# %%
data['Classification']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Classification, Length: 150, dtype: object

# %% [markdown]
# # Qn3. Calculate the mean of each column of the dataset.

# %%
#To calculate mean of each column
data.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Qn4. Check for the null values present in the dataset.

# %%
#To check whether null values present in data set.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
#  From this it is clear that no column have null values. Every column have 150 non-null values

# %% [markdown]
# # Qn5. Visualizations using the dataset.

# %%
#Comparison of sepal length of each flower
#To import matplot and seaborn
import matplotlib.pyplot as plt
import seaborn as sns
#To plot the graph showing the values of sepal lengths of each flower
sns.violinplot(x='Classification',y='SL',data=data)
#To give title for figure
plt.title('Comparison of Sepal Length of each flower',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Comparison of Sepal Length of each flower')

# %%
#Comparison of Sepal width of each flower
sns.boxplot(x='Classification',y='SW',data=data)
plt.title('Comparison of Sepal Width of each flower',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Comparison of Sepal Width of each flower')

# %%
#Comparison of Petal lengths of each flower
sns.stripplot(x='PL',y='Classification',data=data)
plt.title('Comparison of Petal length of each flower',fontsize=20)
#T change the size of the figure
sns.set(rc= {"figure.figsize": (10,6)})

# %%
#Comparison of Petal width of each flower
sns.stripplot(x='Classification',y='PW',data=data)
plt.title('Comparison of Petal width of each flower',fontsize=20)
sns.set(rc= {"figure.figsize": (10,6)})

# %%
#Comparison of petal width and length of each flower
sns.stripplot(x='PL',y='PW',hue='Classification',data=data)
sns.set(rc= {"figure.figsize": (10,6)})
plt.title('Comparison of Petal features of each flower',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Comparison of Petal features of each flower')

# %%
#Comparison of Sepal Width and length of each flower
sns.stripplot(x='SL',y='SW',hue='Classification',data=data)
sns.set(rc= {"figure.figsize": (10,6)})
plt.title('Comparison of Sepal features of each flower',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Comparison of Sepal features of each flower')

# %%
#Comparison of Sepal length and Petal length of each flower
sns.stripplot(x='PL',y='SL',hue='Classification',data=data)
sns.set(rc= {"figure.figsize": (10,6)})
plt.title('Comparison of Sepal length and Petal length of each flower',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Comparison of Sepal length and Petal length of each flower')

# %%
#Comparison of Sepal length and Petal width of each flower
sns.stripplot(x='SL',y='PW',hue='Classification',data=data)
sns.set(rc= {"figure.figsize": (10,6)})
plt.title('Comparison of Sepal length and Petal width of each flower',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Comparison of Sepal length and Petal width of each flower')
